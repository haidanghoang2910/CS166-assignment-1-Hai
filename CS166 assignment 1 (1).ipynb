# %%
import heapq
import scipy.stats as sts
import numpy as np
import matplotlib.pyplot as plt 
import datetime
import random

class Event:
    '''
    Store the properties of one event in the Schedule class defined below. Each
    event has a time at which it needs to run, a function to call when running
    the event, along with the arguments and keyword arguments to pass to that
    function.
    '''
    def __init__(self, timestamp, function, *args, **kwargs):
        self.timestamp = timestamp
        self.function = function
        self.args = args
        self.kwargs = kwargs

    def __lt__(self, other):
        '''
        This overloads the less-than operator in Python. We need it so the
        priority queue knows how to compare two events. We want events with
        earlier (smaller) times to go first.
        '''
        return self.timestamp < other.timestamp

    def run(self, schedule):
        '''
        Run an event by calling the function with its arguments and keyword
        arguments. The first argument to any event function is always the
        schedule in which events are being tracked. The schedule object can be
        used to add new events to the priority queue.
        '''
        self.function(schedule, *self.args, **self.kwargs)


class Schedule:
    '''
    Implement an event schedule using a priority queue. You can add events and
    run the next event.
    
    The `now` attribute contains the time at which the last event was run.
    '''
    
    def __init__(self):
        self.now = 9  # Keep track of the current simulation time
        self.priority_queue = []  # The priority queue of events to run
    
    def add_event_at(self, timestamp, function, *args, **kwargs):
        # Add an event to the schedule at a particular point in time.
        heapq.heappush(
            self.priority_queue,
            Event(timestamp, function, *args, **kwargs))
    
    def add_event_after(self, interval, function, *args, **kwargs):
        # Add an event to the schedule after a specified time interval.
        self.add_event_at(self.now + interval, function, *args, **kwargs)
    
    def next_event_time(self):
        return self.priority_queue[0].timestamp

    def run_next_event(self):
        # Get the next event from the priority queue and run it.
        event = heapq.heappop(self.priority_queue)
        self.now = event.timestamp
        event.run(self)
        
    def __repr__(self):
        return (
            f'Schedule() at time {self.now} ' +
            f'with {len(self.priority_queue)} events in the queue')
    
    def print_events(self):
        print(repr(self))
        for event in sorted(self.priority_queue):
            print(f'   {event.timestamp}: {event.function.__name__}')

# %%
class Queue:
    def __init__(self, service_time_mean, service_time_variance, manager_time_mean, manager_time_variance, queue_index):
        self.queue_index = queue_index #since we have multiple queues, we need an index to mark each queue
        '''
        A truncated normal distribution is used to generate service time and manager's assistance time
        since we cannot have negative time
        '''
        self.service_distribution = sts.truncnorm(
            a=0, b = np.inf, loc=service_time_mean, scale=np.sqrt(service_time_variance))  
        self.manager_distribution = sts.truncnorm(
            a=0, b= np.inf, loc=manager_time_mean, scale=np.sqrt(manager_time_variance))
        # We start with an empty queue and the server not busy
        self.people_in_queue = 0
        self.people_being_served = 0
        self.total_people_arrived=0 
        self.total_people_served=0
        #initiate these to keep track of how many arrived and how many got served in total
        self.list_arrival_time= [] 
        self.list_departure_time= []
        #these are to calculate the waiting time of each customer
        self.max_queue_length=0 
        #this is to record the maximum length reached during the day

    def add_customer(self, schedule):
        # Add the customer to the queue
        self.people_in_queue += 1
        self.total_people_arrived +=1
        if self.queue_index == 0:
            #if it is the manager's queue:
            print(
                f'{str(datetime.timedelta(hours=round(schedule.now,2)))}: Add customer to manager queue.  '
                f'Queue length: {self.people_in_queue}')
            #we don't record the max queue length for manager's queue since it is very likely that it is much lower than
            #other queue lengths and will skew the result of the simulation
            self.list_arrival_time.append(round(schedule.now,2)) 
            if self.people_being_served < 1:
                # This customer can be served immediately
                schedule.add_event_after(0, self.start_serving_customer)
        else:
            #if it is a normal queue
            #Here I switched the reported time to standard time format (hh:mm)
            print(
                f'{str(datetime.timedelta(hours=round(schedule.now,2)))}: Add customer to queue {self.queue_index}.  '
                f'Queue length: {self.people_in_queue}')
            if self.people_in_queue > self.max_queue_length:
                self.max_queue_length = self.people_in_queue 
                #record the maximum queue length
            self.list_arrival_time.append(round(schedule.now,2)) 
            #record the arrival time
            if self.people_being_served < 1:
                # This customer can be served immediately
                schedule.add_event_after(0, self.start_serving_customer)
    def start_serving_customer(self, schedule):
        # Move the customer from the queue to a server
        self.people_in_queue -= 1
        self.people_being_served += 1
        if self.queue_index == 0:
            #if it's the manager's queue:
            print(
                f'{str(datetime.timedelta(hours=round(schedule.now,2)))}: Start serving customer in manager queue. '
                f'Queue {self.queue_index} length: {self.people_in_queue}')
            # Schedule when the manager will be done with the customer. 
            schedule.add_event_after(float(self.manager_distribution.rvs()) + 
                                     float(self.service_distribution.rvs()),self.finish_serving_customer)
            #we add the service time too since manager assistance is extended service
        else:
            #if it's a normal queue
            print(
                f'{str(datetime.timedelta(hours=round(schedule.now,2)))}: Start serving customer in queue {self.queue_index}. '
                f'Queue {self.queue_index} length: {self.people_in_queue}')
            # Schedule when the server will be done with the customer. 
            schedule.add_event_after(float(self.service_distribution.rvs()),self.finish_serving_customer)

    def finish_serving_customer(self, schedule):
        # Remove the customer from the server
        self.people_being_served -= 1
        if self.queue_index == 0:
            #if it's the manager's queue
            print(
                f'{str(datetime.timedelta(hours=round(schedule.now,2)))}: Stop serving customer in manager queue.  '
                f'Queue {self.queue_index} length: {self.people_in_queue}')
            self.list_departure_time.append(round(schedule.now,2))
        else:
            print(
                f'{str(datetime.timedelta(hours=round(schedule.now,2)))}: Stop serving customer in queue {self.queue_index}.  '
                f'Queue {self.queue_index} length: {self.people_in_queue}')
            self.list_departure_time.append(round(schedule.now,2))
        self.total_people_served += 1
        if self.people_in_queue > 0:
            # There are more people in the queue so serve the next customer
            schedule.add_event_after(0, self.start_serving_customer)

# %%
class GroceryStore:
    
    def __init__(self, arrival_rate, service_rate, service_time_variance, manager_time_mean, manager_time_variance, nqueue):
        self.nqueue = nqueue+1 #1 extra queue for the manager since we only have 1 manager
        #initiate this attribute to plug in different numbers of queue
        self.list_of_queue=[]
        #we need this list since we have multiple queues
        for i in range(self.nqueue):
            self.list_of_queue.append(Queue(
                service_rate, service_time_variance, manager_time_mean, manager_time_variance,i))
        #let's consider the first queue (index 0) to be the manager's queue
        #initiate the queues along with their indices
        self.arrival_distribution = sts.expon(scale=1/arrival_rate)


    def add_customer(self, schedule):
        # Add this customer to the shortest queue
        #find the shortest queue:
        list_of_queue_length=[]
        for i in range(1,self.nqueue):
            list_of_queue_length.append(self.list_of_queue[i].people_in_queue)
        min_queue_index = list_of_queue_length.index(min(list_of_queue_length)) + 1
        #now we have the index of the shortest queue
        print("Queue to add customer:", min_queue_index)
        self.list_of_queue[min_queue_index].add_customer(schedule)
        #adds customer to the shortest queue
        chance_of_getting_manager = random.random()
        if chance_of_getting_manager <= 0.05:
            self.list_of_queue[0].add_customer(schedule)
        #5% of the time we add customers to the manager's queue
        # Schedule when to add another customer
        schedule.add_event_after(
            self.arrival_distribution.rvs(),
            self.add_customer)

    def run(self, schedule):
        # Schedule when the first customer arrives
        schedule.add_event_after(
            self.arrival_distribution.rvs(),
            self.add_customer)

# %%
def run_simulation(arrival_rate, service_rate, service_time_variance, manager_rate, 
                   manager_time_variance, run_until, nqueue):
    customer_over_time = {}
    #list to record total number of customers later to graph
    schedule = Schedule()
    grocery_store = GroceryStore(
        arrival_rate, service_rate, service_time_variance, manager_rate, manager_time_variance, nqueue)
    grocery_store.run(schedule)
    while schedule.next_event_time() < run_until:
        schedule.run_next_event()
        total_number_in_queue = 0
        #initiate this counter to count the total number of people in all queues
        for i in grocery_store.list_of_queue:
            total_number_in_queue += i.people_in_queue
        customer_over_time[schedule.now] = total_number_in_queue/10
        #divide this counter by 10 we have the average number of people in each queue (or queue length)
    plt.scatter(customer_over_time.keys(), customer_over_time.values(), s = 5, color='black')
    plt.ylabel('Average length of queues (people)')
    plt.xlabel('Time (hour)')
    plt.title("Average length of queues over time")
    list_waiting_time=[]
    for i in grocery_store.list_of_queue:
        print("Total customers arrived in queue", i.queue_index, "is", i.total_people_arrived)
        print("Total customers served in queue", i.queue_index, "is", i.total_people_served)
        for j in range(len(i.list_departure_time)-1):
            list_waiting_time.append(i.list_departure_time[j]-i.list_arrival_time[j])
            #waiting time is equal to departure time minus arrival time

    print("Average waiting time in minutes is", np.mean(list_waiting_time)*60)
    return grocery_store

# %%
#We run 1 instance to prove that the code works
arrival = 60 #go by the hour: 1 customer per min so 60 customers per hour 
#convert all these parameters into hours
service = 3/60
service_variance = 1/60
manager = 4/60
manager_variance = 1/60
duration = 18
service_time_variance = 1/60
queue_num = 9
grocery_store = run_simulation(arrival, service, service_variance, manager, manager_variance, duration, queue_num)
# Out:
# Queue to add customer: 1
# 9:02:24: Add customer to queue 1.  Queue length: 1
# 9:02:24: Start serving customer in queue 1. Queue 1 length: 0
# Queue to add customer: 1
# 9:03:00: Add customer to queue 1.  Queue length: 1
# Queue to add customer: 2
# 9:03:36: Add customer to queue 2.  Queue length: 1
# 9:03:36: Start serving customer in queue 2. Queue 2 length: 0
# Queue to add customer: 2
# 9:04:12: Add customer to queue 2.  Queue length: 1
# Queue to add customer: 3
# 9:04:48: Add customer to queue 3.  Queue length: 1
# 9:04:48: Start serving customer in queue 3. Queue 3 length: 0
# Queue to add customer: 3
# 9:07:48: Add customer to queue 3.  Queue length: 1
# 9:09:36: Stop serving customer in queue 2.  Queue 2 length: 1
# 9:09:36: Start serving customer in queue 2. Queue 2 length: 0
# Queue to add customer: 2
# 9:10:12: Add customer to queue 2.  Queue length: 1
# 9:12:00: Stop serving customer in queue 3.  Queue 3 length: 1
# 9:12:00: Start serving customer in queue 3. Queue 3 length: 0
# Queue to add customer: 3
# 9:12:00: Add customer to queue 3.  Queue length: 1
# Queue to add customer: 4
# 9:12:00: Add customer to queue 4.  Queue length: 1
# 9:12:00: Start serving customer in queue 4. Queue 4 length: 0
# Queue to add customer: 4
# 9:15:36: Add customer to queue 4.  Queue length: 1
# 9:16:12: Stop serving customer in queue 2.  Queue 2 length: 1
# 9:16:12: Start serving customer in queue 2. Queue 2 length: 0
# Queue to add customer: 2
# 9:18:00: Add customer to queue 2.  Queue length: 1
# Queue to add customer: 5
# 9:18:00: Add customer to queue 5.  Queue length: 1
# 9:18:00: Start serving customer in queue 5. Queue 5 length: 0
# Queue to add customer: 5
# 9:18:36: Add customer to queue 5.  Queue length: 1
# Queue to add customer: 6
# 9:19:12: Add customer to queue 6.  Queue length: 1
# 9:19:12: Start serving customer in queue 6. Queue 6 length: 0
# 9:19:12: Stop serving customer in queue 4.  Queue 4 length: 1
# 9:19:12: Start serving customer in queue 4. Queue 4 length: 0
# Queue to add customer: 4
# 9:20:24: Add customer to queue 4.  Queue length: 1
# Queue to add customer: 6
# 9:20:24: Add customer to queue 6.  Queue length: 1
# 9:21:00: Stop serving customer in queue 1.  Queue 1 length: 1
# 9:21:00: Start serving customer in queue 1. Queue 1 length: 0
# Queue to add customer: 1
# 9:22:12: Add customer to queue 1.  Queue length: 1
# Queue to add customer: 7
# 9:22:12: Add customer to queue 7.  Queue length: 1
# 9:22:12: Start serving customer in queue 7. Queue 7 length: 0
# Queue to add customer: 7
# 9:22:12: Add customer to queue 7.  Queue length: 1
# Queue to add customer: 8
# 9:22:48: Add customer to queue 8.  Queue length: 1
# 9:22:48: Start serving customer in queue 8. Queue 8 length: 0
# Queue to add customer: 8
# 9:23:24: Add customer to queue 8.  Queue length: 1
# Queue to add customer: 9
# 9:23:24: Add customer to queue 9.  Queue length: 1
# 9:23:24: Start serving customer in queue 9. Queue 9 length: 0
# 9:24:00: Stop serving customer in queue 4.  Queue 4 length: 1
# 9:24:00: Start serving customer in queue 4. Queue 4 length: 0
# 9:24:00: Stop serving customer in queue 3.  Queue 3 length: 1
# 9:24:00: Start serving customer in queue 3. Queue 3 length: 0
# Queue to add customer: 3
# 9:24:36: Add customer to queue 3.  Queue length: 1
# Queue to add customer: 4
# 9:24:36: Add customer to queue 4.  Queue length: 1
# Queue to add customer: 9
# 9:25:48: Add customer to queue 9.  Queue length: 1
# Queue to add customer: 1
# 9:25:48: Add customer to queue 1.  Queue length: 2
# Queue to add customer: 2
# 9:27:00: Add customer to queue 2.  Queue length: 2
# 9:27:00: Add customer to manager queue.  Queue length: 1
# 9:27:00: Start serving customer in manager queue. Queue 0 length: 0
# Queue to add customer: 3
# 9:27:36: Add customer to queue 3.  Queue length: 2
# 9:27:36: Stop serving customer in queue 4.  Queue 4 length: 1
# 9:27:36: Start serving customer in queue 4. Queue 4 length: 0
# Queue to add customer: 4
# 9:28:12: Add customer to queue 4.  Queue length: 1
# Queue to add customer: 4
# 9:28:12: Add customer to queue 4.  Queue length: 2
# 9:28:12: Stop serving customer in queue 7.  Queue 7 length: 1
# 9:28:12: Start serving customer in queue 7. Queue 7 length: 0
# 9:28:48: Stop serving customer in queue 2.  Queue 2 length: 2
# 9:28:48: Start serving customer in queue 2. Queue 2 length: 1
# Queue to add customer: 7
# 9:28:48: Add customer to queue 7.  Queue length: 1
# 9:28:48: Stop serving customer in queue 8.  Queue 8 length: 1
# 9:28:48: Start serving customer in queue 8. Queue 8 length: 0
# Queue to add customer: 8
# 9:30:00: Add customer to queue 8.  Queue length: 1
# Queue to add customer: 2
# 9:30:36: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 5
# 9:31:12: Add customer to queue 5.  Queue length: 2
# 9:31:12: Stop serving customer in queue 1.  Queue 1 length: 2
# 9:31:12: Start serving customer in queue 1. Queue 1 length: 1
# 9:31:48: Stop serving customer in queue 5.  Queue 5 length: 2
# 9:31:48: Start serving customer in queue 5. Queue 5 length: 1
# 9:33:00: Stop serving customer in queue 2.  Queue 2 length: 2
# 9:33:00: Start serving customer in queue 2. Queue 2 length: 1
# Queue to add customer: 1
# 9:33:36: Add customer to queue 1.  Queue length: 2
# Queue to add customer: 2
# 9:34:12: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 5
# 9:34:12: Add customer to queue 5.  Queue length: 2
# 9:35:24: Stop serving customer in queue 5.  Queue 5 length: 2
# 9:35:24: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 5
# 9:35:24: Add customer to queue 5.  Queue length: 2
# Queue to add customer: 6
# 9:36:00: Add customer to queue 6.  Queue length: 2
# 9:36:36: Stop serving customer in queue 1.  Queue 1 length: 2
# 9:36:36: Start serving customer in queue 1. Queue 1 length: 1
# 9:36:36: Stop serving customer in queue 4.  Queue 4 length: 2
# 9:36:36: Start serving customer in queue 4. Queue 4 length: 1
# 9:36:36: Stop serving customer in queue 3.  Queue 3 length: 2
# 9:36:36: Start serving customer in queue 3. Queue 3 length: 1
# 9:36:36: Stop serving customer in queue 6.  Queue 6 length: 2
# 9:36:36: Start serving customer in queue 6. Queue 6 length: 1
# 9:37:48: Stop serving customer in queue 8.  Queue 8 length: 1
# 9:37:48: Start serving customer in queue 8. Queue 8 length: 0
# Queue to add customer: 8
# 9:37:48: Add customer to queue 8.  Queue length: 1
# Queue to add customer: 1
# 9:39:00: Add customer to queue 1.  Queue length: 2
# 9:39:36: Stop serving customer in queue 2.  Queue 2 length: 2
# 9:39:36: Start serving customer in queue 2. Queue 2 length: 1
# 9:39:36: Stop serving customer in queue 7.  Queue 7 length: 1
# 9:39:36: Start serving customer in queue 7. Queue 7 length: 0
# 9:40:12: Stop serving customer in queue 1.  Queue 1 length: 2
# 9:40:12: Start serving customer in queue 1. Queue 1 length: 1
# Queue to add customer: 7
# 9:40:12: Add customer to queue 7.  Queue length: 1
# 9:40:48: Stop serving customer in queue 9.  Queue 9 length: 1
# 9:40:48: Start serving customer in queue 9. Queue 9 length: 0
# Queue to add customer: 9
# 9:40:48: Add customer to queue 9.  Queue length: 1
# 9:42:00: Stop serving customer in manager queue.  Queue 0 length: 0
# Queue to add customer: 1
# 9:42:36: Add customer to queue 1.  Queue length: 2
# 9:42:36: Stop serving customer in queue 5.  Queue 5 length: 2
# 9:42:36: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 2
# 9:43:12: Add customer to queue 2.  Queue length: 2
# 9:43:12: Stop serving customer in queue 8.  Queue 8 length: 1
# 9:43:12: Start serving customer in queue 8. Queue 8 length: 0
# Queue to add customer: 8
# 9:45:00: Add customer to queue 8.  Queue length: 1
# Queue to add customer: 3
# 9:46:12: Add customer to queue 3.  Queue length: 2
# Queue to add customer: 4
# 9:46:48: Add customer to queue 4.  Queue length: 2
# 9:46:48: Stop serving customer in queue 3.  Queue 3 length: 2
# 9:46:48: Start serving customer in queue 3. Queue 3 length: 1
# 9:46:48: Stop serving customer in queue 5.  Queue 5 length: 1
# 9:46:48: Start serving customer in queue 5. Queue 5 length: 0
# 9:47:24: Stop serving customer in queue 4.  Queue 4 length: 2
# 9:47:24: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 5
# 9:48:00: Add customer to queue 5.  Queue length: 1
# 9:48:00: Add customer to manager queue.  Queue length: 1
# 9:48:00: Start serving customer in manager queue. Queue 0 length: 0
# Queue to add customer: 3
# 9:51:00: Add customer to queue 3.  Queue length: 2
# Queue to add customer: 4
# 9:51:00: Add customer to queue 4.  Queue length: 2
# 9:51:00: Stop serving customer in queue 3.  Queue 3 length: 2
# 9:51:00: Start serving customer in queue 3. Queue 3 length: 1
# 9:51:00: Stop serving customer in queue 4.  Queue 4 length: 2
# 9:51:00: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 3
# 9:52:12: Add customer to queue 3.  Queue length: 2
# Queue to add customer: 4
# 9:52:48: Add customer to queue 4.  Queue length: 2
# 9:53:24: Stop serving customer in queue 2.  Queue 2 length: 2
# 9:53:24: Start serving customer in queue 2. Queue 2 length: 1
# 9:53:24: Stop serving customer in queue 1.  Queue 1 length: 2
# 9:53:24: Start serving customer in queue 1. Queue 1 length: 1
# 9:54:00: Stop serving customer in queue 6.  Queue 6 length: 1
# 9:54:00: Start serving customer in queue 6. Queue 6 length: 0
# 9:54:00: Stop serving customer in queue 7.  Queue 7 length: 1
# 9:54:00: Start serving customer in queue 7. Queue 7 length: 0
# Queue to add customer: 6
# 9:54:00: Add customer to queue 6.  Queue length: 1
# 9:54:36: Stop serving customer in queue 4.  Queue 4 length: 2
# 9:54:36: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 7
# 9:55:12: Add customer to queue 7.  Queue length: 1
# Queue to add customer: 1
# 9:55:48: Add customer to queue 1.  Queue length: 2
# Queue to add customer: 2
# 9:56:24: Add customer to queue 2.  Queue length: 2
# 9:56:24: Add customer to manager queue.  Queue length: 1
# Queue to add customer: 4
# 9:56:24: Add customer to queue 4.  Queue length: 2
# Queue to add customer: 5
# 9:57:00: Add customer to queue 5.  Queue length: 2
# Queue to add customer: 6
# 9:57:36: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 7
# 9:57:36: Add customer to queue 7.  Queue length: 2
# 9:58:12: Stop serving customer in queue 2.  Queue 2 length: 2
# 9:58:12: Start serving customer in queue 2. Queue 2 length: 1
# 9:58:12: Stop serving customer in queue 4.  Queue 4 length: 2
# 9:58:12: Start serving customer in queue 4. Queue 4 length: 1
# 9:58:48: Stop serving customer in manager queue.  Queue 0 length: 1
# 9:58:48: Start serving customer in manager queue. Queue 0 length: 0
# 9:58:48: Stop serving customer in queue 7.  Queue 7 length: 2
# 9:58:48: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 2
# 9:59:24: Add customer to queue 2.  Queue length: 2
# 10:00:00: Stop serving customer in queue 5.  Queue 5 length: 2
# 10:00:00: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 4
# 10:00:00: Add customer to queue 4.  Queue length: 2
# Queue to add customer: 5
# 10:01:12: Add customer to queue 5.  Queue length: 2
# 10:01:12: Stop serving customer in queue 9.  Queue 9 length: 1
# 10:01:12: Start serving customer in queue 9. Queue 9 length: 0
# Queue to add customer: 9
# 10:03:00: Add customer to queue 9.  Queue length: 1
# 10:03:00: Stop serving customer in queue 8.  Queue 8 length: 1
# 10:03:00: Start serving customer in queue 8. Queue 8 length: 0
# 10:03:36: Stop serving customer in queue 4.  Queue 4 length: 2
# 10:03:36: Start serving customer in queue 4. Queue 4 length: 1
# 10:03:36: Stop serving customer in queue 3.  Queue 3 length: 2
# 10:03:36: Start serving customer in queue 3. Queue 3 length: 1
# Queue to add customer: 8
# 10:04:12: Add customer to queue 8.  Queue length: 1
# 10:04:12: Stop serving customer in queue 2.  Queue 2 length: 2
# 10:04:12: Start serving customer in queue 2. Queue 2 length: 1
# Queue to add customer: 2
# 10:05:24: Add customer to queue 2.  Queue length: 2
# 10:06:00: Stop serving customer in queue 1.  Queue 1 length: 2
# 10:06:00: Start serving customer in queue 1. Queue 1 length: 1
# Queue to add customer: 1
# 10:06:36: Add customer to queue 1.  Queue length: 2
# Queue to add customer: 3
# 10:06:36: Add customer to queue 3.  Queue length: 2
# 10:06:36: Stop serving customer in queue 9.  Queue 9 length: 1
# 10:06:36: Start serving customer in queue 9. Queue 9 length: 0
# 10:07:12: Stop serving customer in queue 6.  Queue 6 length: 2
# 10:07:12: Start serving customer in queue 6. Queue 6 length: 1
# 10:07:12: Stop serving customer in queue 4.  Queue 4 length: 1
# 10:07:12: Start serving customer in queue 4. Queue 4 length: 0
# Queue to add customer: 4
# 10:08:24: Add customer to queue 4.  Queue length: 1
# Queue to add customer: 9
# 10:08:24: Add customer to queue 9.  Queue length: 1
# Queue to add customer: 4
# 10:08:24: Add customer to queue 4.  Queue length: 2
# Queue to add customer: 6
# 10:09:00: Add customer to queue 6.  Queue length: 2
# 10:09:00: Stop serving customer in queue 3.  Queue 3 length: 2
# 10:09:00: Start serving customer in queue 3. Queue 3 length: 1
# Queue to add customer: 3
# 10:09:36: Add customer to queue 3.  Queue length: 2
# 10:09:36: Stop serving customer in queue 8.  Queue 8 length: 1
# 10:09:36: Start serving customer in queue 8. Queue 8 length: 0
# 10:10:12: Stop serving customer in queue 7.  Queue 7 length: 1
# 10:10:12: Start serving customer in queue 7. Queue 7 length: 0
# 10:10:48: Stop serving customer in queue 5.  Queue 5 length: 2
# 10:10:48: Start serving customer in queue 5. Queue 5 length: 1
# 10:10:48: Stop serving customer in queue 2.  Queue 2 length: 2
# 10:10:48: Start serving customer in queue 2. Queue 2 length: 1
# 10:10:48: Stop serving customer in manager queue.  Queue 0 length: 0
# Queue to add customer: 7
# 10:12:36: Add customer to queue 7.  Queue length: 1
# 10:13:12: Stop serving customer in queue 9.  Queue 9 length: 1
# 10:13:12: Start serving customer in queue 9. Queue 9 length: 0
# Queue to add customer: 8
# 10:13:12: Add customer to queue 8.  Queue length: 1
# 10:13:12: Add customer to manager queue.  Queue length: 1
# 10:13:12: Start serving customer in manager queue. Queue 0 length: 0
# 10:13:48: Stop serving customer in queue 7.  Queue 7 length: 1
# 10:13:48: Start serving customer in queue 7. Queue 7 length: 0
# Queue to add customer: 7
# 10:13:48: Add customer to queue 7.  Queue length: 1
# Queue to add customer: 9
# 10:15:00: Add customer to queue 9.  Queue length: 1
# Queue to add customer: 2
# 10:15:00: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 5
# 10:15:00: Add customer to queue 5.  Queue length: 2
# 10:15:00: Stop serving customer in queue 8.  Queue 8 length: 1
# 10:15:00: Start serving customer in queue 8. Queue 8 length: 0
# Queue to add customer: 8
# 10:15:36: Add customer to queue 8.  Queue length: 1
# 10:16:12: Stop serving customer in queue 6.  Queue 6 length: 2
# 10:16:12: Start serving customer in queue 6. Queue 6 length: 1
# 10:16:12: Stop serving customer in queue 1.  Queue 1 length: 2
# 10:16:12: Start serving customer in queue 1. Queue 1 length: 1
# Queue to add customer: 1
# 10:16:48: Add customer to queue 1.  Queue length: 2
# Queue to add customer: 6
# 10:17:24: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 7
# 10:17:24: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 8
# 10:18:00: Add customer to queue 8.  Queue length: 2
# 10:19:12: Stop serving customer in queue 3.  Queue 3 length: 2
# 10:19:12: Start serving customer in queue 3. Queue 3 length: 1
# 10:19:48: Stop serving customer in queue 5.  Queue 5 length: 2
# 10:19:48: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 3
# 10:19:48: Add customer to queue 3.  Queue length: 2
# 10:19:48: Stop serving customer in queue 8.  Queue 8 length: 2
# 10:19:48: Start serving customer in queue 8. Queue 8 length: 1
# Queue to add customer: 5
# 10:20:24: Add customer to queue 5.  Queue length: 2
# 10:20:24: Stop serving customer in queue 6.  Queue 6 length: 2
# 10:20:24: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 6
# 10:21:00: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 8
# 10:21:00: Add customer to queue 8.  Queue length: 2
# 10:21:36: Stop serving customer in queue 4.  Queue 4 length: 2
# 10:21:36: Start serving customer in queue 4. Queue 4 length: 1
# 10:21:36: Stop serving customer in queue 9.  Queue 9 length: 1
# 10:21:36: Start serving customer in queue 9. Queue 9 length: 0
# 10:22:48: Stop serving customer in queue 5.  Queue 5 length: 2
# 10:22:48: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 9
# 10:22:48: Add customer to queue 9.  Queue length: 1
# 10:22:48: Add customer to manager queue.  Queue length: 1
# Queue to add customer: 4
# 10:23:24: Add customer to queue 4.  Queue length: 2
# 10:23:24: Stop serving customer in queue 2.  Queue 2 length: 2
# 10:23:24: Start serving customer in queue 2. Queue 2 length: 1
# Queue to add customer: 2
# 10:24:36: Add customer to queue 2.  Queue length: 2
# 10:25:12: Stop serving customer in queue 8.  Queue 8 length: 2
# 10:25:12: Start serving customer in queue 8. Queue 8 length: 1
# Queue to add customer: 5
# 10:25:12: Add customer to queue 5.  Queue length: 2
# 10:25:48: Stop serving customer in queue 6.  Queue 6 length: 2
# 10:25:48: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 6
# 10:25:48: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 8
# 10:26:24: Add customer to queue 8.  Queue length: 2
# 10:27:00: Stop serving customer in queue 2.  Queue 2 length: 2
# 10:27:00: Start serving customer in queue 2. Queue 2 length: 1
# 10:27:36: Stop serving customer in queue 3.  Queue 3 length: 2
# 10:27:36: Start serving customer in queue 3. Queue 3 length: 1
# Queue to add customer: 2
# 10:27:36: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 3
# 10:27:36: Add customer to queue 3.  Queue length: 2
# 10:28:12: Stop serving customer in queue 9.  Queue 9 length: 1
# 10:28:12: Start serving customer in queue 9. Queue 9 length: 0
# Queue to add customer: 9
# 10:28:12: Add customer to queue 9.  Queue length: 1
# Queue to add customer: 9
# 10:28:48: Add customer to queue 9.  Queue length: 2
# 10:29:24: Stop serving customer in queue 1.  Queue 1 length: 2
# 10:29:24: Start serving customer in queue 1. Queue 1 length: 1
# Queue to add customer: 1
# 10:29:24: Add customer to queue 1.  Queue length: 2
# 10:30:00: Stop serving customer in queue 8.  Queue 8 length: 2
# 10:30:00: Start serving customer in queue 8. Queue 8 length: 1
# 10:30:36: Stop serving customer in manager queue.  Queue 0 length: 1
# 10:30:36: Start serving customer in manager queue. Queue 0 length: 0
# 10:31:12: Stop serving customer in queue 7.  Queue 7 length: 2
# 10:31:12: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 7
# 10:31:12: Add customer to queue 7.  Queue length: 2
# 10:31:12: Stop serving customer in queue 4.  Queue 4 length: 2
# 10:31:12: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 4
# 10:31:48: Add customer to queue 4.  Queue length: 2
# 10:32:24: Stop serving customer in queue 6.  Queue 6 length: 2
# 10:32:24: Start serving customer in queue 6. Queue 6 length: 1
# 10:32:24: Stop serving customer in queue 2.  Queue 2 length: 2
# 10:32:24: Start serving customer in queue 2. Queue 2 length: 1
# Queue to add customer: 2
# 10:33:36: Add customer to queue 2.  Queue length: 2
# 10:33:36: Add customer to manager queue.  Queue length: 1
# Queue to add customer: 6
# 10:33:36: Add customer to queue 6.  Queue length: 2
# 10:33:36: Stop serving customer in queue 9.  Queue 9 length: 2
# 10:33:36: Start serving customer in queue 9. Queue 9 length: 1
# Queue to add customer: 8
# 10:34:12: Add customer to queue 8.  Queue length: 2
# Queue to add customer: 9
# 10:34:12: Add customer to queue 9.  Queue length: 2
# Queue to add customer: 1
# 10:34:12: Add customer to queue 1.  Queue length: 3
# Queue to add customer: 2
# 10:34:12: Add customer to queue 2.  Queue length: 3
# 10:36:00: Stop serving customer in queue 1.  Queue 1 length: 3
# 10:36:00: Start serving customer in queue 1. Queue 1 length: 2
# Queue to add customer: 1
# 10:37:12: Add customer to queue 1.  Queue length: 3
# 10:37:48: Stop serving customer in queue 4.  Queue 4 length: 2
# 10:37:48: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 4
# 10:39:00: Add customer to queue 4.  Queue length: 2
# 10:39:00: Add customer to manager queue.  Queue length: 2
# Queue to add customer: 3
# 10:39:36: Add customer to queue 3.  Queue length: 3
# 10:39:36: Stop serving customer in queue 2.  Queue 2 length: 3
# 10:39:36: Start serving customer in queue 2. Queue 2 length: 2
# Queue to add customer: 2
# 10:39:36: Add customer to queue 2.  Queue length: 3
# 10:40:48: Stop serving customer in manager queue.  Queue 0 length: 2
# 10:40:48: Start serving customer in manager queue. Queue 0 length: 1
# Queue to add customer: 4
# 10:42:00: Add customer to queue 4.  Queue length: 3
# Queue to add customer: 5
# 10:42:36: Add customer to queue 5.  Queue length: 3
# 10:42:36: Stop serving customer in queue 4.  Queue 4 length: 3
# 10:42:36: Start serving customer in queue 4. Queue 4 length: 2
# 10:42:36: Stop serving customer in queue 3.  Queue 3 length: 3
# 10:42:36: Start serving customer in queue 3. Queue 3 length: 2
# Queue to add customer: 3
# 10:43:12: Add customer to queue 3.  Queue length: 3
# Queue to add customer: 4
# 10:43:12: Add customer to queue 4.  Queue length: 3
# 10:43:12: Stop serving customer in queue 6.  Queue 6 length: 2
# 10:43:12: Start serving customer in queue 6. Queue 6 length: 1
# 10:43:48: Stop serving customer in queue 2.  Queue 2 length: 3
# 10:43:48: Start serving customer in queue 2. Queue 2 length: 2
# 10:43:48: Stop serving customer in queue 5.  Queue 5 length: 3
# 10:43:48: Start serving customer in queue 5. Queue 5 length: 2
# Queue to add customer: 6
# 10:44:24: Add customer to queue 6.  Queue length: 2
# 10:44:24: Stop serving customer in queue 7.  Queue 7 length: 2
# 10:44:24: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 7
# 10:45:00: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 2
# 10:45:00: Add customer to queue 2.  Queue length: 3
# 10:46:12: Stop serving customer in queue 9.  Queue 9 length: 2
# 10:46:12: Start serving customer in queue 9. Queue 9 length: 1
# Queue to add customer: 9
# 10:47:24: Add customer to queue 9.  Queue length: 2
# 10:47:24: Stop serving customer in queue 8.  Queue 8 length: 2
# 10:47:24: Start serving customer in queue 8. Queue 8 length: 1
# Queue to add customer: 8
# 10:47:24: Add customer to queue 8.  Queue length: 2
# 10:48:00: Stop serving customer in queue 3.  Queue 3 length: 3
# 10:48:00: Start serving customer in queue 3. Queue 3 length: 2
# 10:48:36: Stop serving customer in queue 2.  Queue 2 length: 3
# 10:48:36: Start serving customer in queue 2. Queue 2 length: 2
# 10:49:48: Stop serving customer in queue 5.  Queue 5 length: 2
# 10:49:48: Start serving customer in queue 5. Queue 5 length: 1
# 10:50:24: Stop serving customer in queue 6.  Queue 6 length: 2
# 10:50:24: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 5
# 10:51:00: Add customer to queue 5.  Queue length: 2
# Queue to add customer: 6
# 10:51:36: Add customer to queue 6.  Queue length: 2
# 10:51:36: Add customer to manager queue.  Queue length: 2
# 10:51:36: Stop serving customer in queue 1.  Queue 1 length: 3
# 10:51:36: Start serving customer in queue 1. Queue 1 length: 2
# Queue to add customer: 1
# 10:51:36: Add customer to queue 1.  Queue length: 3
# 10:53:24: Stop serving customer in queue 3.  Queue 3 length: 2
# 10:53:24: Start serving customer in queue 3. Queue 3 length: 1
# 10:53:24: Stop serving customer in queue 7.  Queue 7 length: 2
# 10:53:24: Start serving customer in queue 7. Queue 7 length: 1
# 10:53:24: Stop serving customer in queue 4.  Queue 4 length: 3
# 10:53:24: Start serving customer in queue 4. Queue 4 length: 2
# Queue to add customer: 3
# 10:54:00: Add customer to queue 3.  Queue length: 2
# 10:54:00: Stop serving customer in queue 9.  Queue 9 length: 2
# 10:54:00: Start serving customer in queue 9. Queue 9 length: 1
# Queue to add customer: 7
# 10:55:12: Add customer to queue 7.  Queue length: 2
# 10:56:24: Stop serving customer in queue 3.  Queue 3 length: 2
# 10:56:24: Start serving customer in queue 3. Queue 3 length: 1
# Queue to add customer: 3
# 10:57:00: Add customer to queue 3.  Queue length: 2
# 10:57:36: Stop serving customer in queue 5.  Queue 5 length: 2
# 10:57:36: Start serving customer in queue 5. Queue 5 length: 1
# 10:57:36: Stop serving customer in queue 8.  Queue 8 length: 2
# 10:57:36: Start serving customer in queue 8. Queue 8 length: 1
# Queue to add customer: 5
# 10:58:12: Add customer to queue 5.  Queue length: 2
# 10:58:12: Stop serving customer in queue 1.  Queue 1 length: 3
# 10:58:12: Start serving customer in queue 1. Queue 1 length: 2
# Queue to add customer: 8
# 10:59:24: Add customer to queue 8.  Queue length: 2
# 11:00:00: Stop serving customer in queue 7.  Queue 7 length: 2
# 11:00:00: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 7
# 11:00:36: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 9
# 11:00:36: Add customer to queue 9.  Queue length: 2
# 11:00:36: Stop serving customer in queue 4.  Queue 4 length: 2
# 11:00:36: Start serving customer in queue 4. Queue 4 length: 1
# 11:01:48: Stop serving customer in queue 6.  Queue 6 length: 2
# 11:01:48: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 4
# 11:01:48: Add customer to queue 4.  Queue length: 2
# 11:02:24: Stop serving customer in queue 5.  Queue 5 length: 2
# 11:02:24: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 5
# 11:03:00: Add customer to queue 5.  Queue length: 2
# Queue to add customer: 6
# 11:04:12: Add customer to queue 6.  Queue length: 2
# 11:04:12: Stop serving customer in queue 1.  Queue 1 length: 2
# 11:04:12: Start serving customer in queue 1. Queue 1 length: 1
# Queue to add customer: 1
# 11:04:12: Add customer to queue 1.  Queue length: 2
# Queue to add customer: 1
# 11:04:48: Add customer to queue 1.  Queue length: 3
# Queue to add customer: 2
# 11:05:24: Add customer to queue 2.  Queue length: 3
# 11:06:36: Stop serving customer in queue 3.  Queue 3 length: 2
# 11:06:36: Start serving customer in queue 3. Queue 3 length: 1
# 11:06:36: Stop serving customer in queue 8.  Queue 8 length: 2
# 11:06:36: Start serving customer in queue 8. Queue 8 length: 1
# Queue to add customer: 3
# 11:07:12: Add customer to queue 3.  Queue length: 2
# 11:09:00: Stop serving customer in queue 6.  Queue 6 length: 2
# 11:09:00: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 6
# 11:09:00: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 8
# 11:09:36: Add customer to queue 8.  Queue length: 2
# Queue to add customer: 3
# 11:10:12: Add customer to queue 3.  Queue length: 3
# 11:10:12: Stop serving customer in manager queue.  Queue 0 length: 2
# 11:10:12: Start serving customer in manager queue. Queue 0 length: 1
# 11:10:12: Stop serving customer in queue 9.  Queue 9 length: 2
# 11:10:12: Start serving customer in queue 9. Queue 9 length: 1
# 11:11:24: Stop serving customer in queue 2.  Queue 2 length: 3
# 11:11:24: Start serving customer in queue 2. Queue 2 length: 2
# 11:11:24: Stop serving customer in queue 1.  Queue 1 length: 3
# 11:11:24: Start serving customer in queue 1. Queue 1 length: 2
# Queue to add customer: 9
# 11:11:24: Add customer to queue 9.  Queue length: 2
# 11:12:00: Stop serving customer in queue 7.  Queue 7 length: 2
# 11:12:00: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 7
# 11:12:00: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 1
# 11:13:48: Add customer to queue 1.  Queue length: 3
# 11:14:24: Stop serving customer in queue 5.  Queue 5 length: 2
# 11:14:24: Start serving customer in queue 5. Queue 5 length: 1
# 11:15:00: Stop serving customer in queue 8.  Queue 8 length: 2
# 11:15:00: Start serving customer in queue 8. Queue 8 length: 1
# 11:16:12: Stop serving customer in queue 3.  Queue 3 length: 3
# 11:16:12: Start serving customer in queue 3. Queue 3 length: 2
# Queue to add customer: 5
# 11:16:12: Add customer to queue 5.  Queue length: 2
# 11:16:12: Stop serving customer in queue 4.  Queue 4 length: 2
# 11:16:12: Start serving customer in queue 4. Queue 4 length: 1
# 11:19:12: Stop serving customer in queue 9.  Queue 9 length: 2
# 11:19:12: Start serving customer in queue 9. Queue 9 length: 1
# 11:19:48: Stop serving customer in queue 2.  Queue 2 length: 2
# 11:19:48: Start serving customer in queue 2. Queue 2 length: 1
# Queue to add customer: 2
# 11:19:48: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 4
# 11:21:00: Add customer to queue 4.  Queue length: 2
# Queue to add customer: 8
# 11:21:00: Add customer to queue 8.  Queue length: 2
# 11:21:00: Stop serving customer in queue 1.  Queue 1 length: 3
# 11:21:00: Start serving customer in queue 1. Queue 1 length: 2
# Queue to add customer: 9
# 11:21:00: Add customer to queue 9.  Queue length: 2
# 11:21:00: Stop serving customer in queue 6.  Queue 6 length: 2
# 11:21:00: Start serving customer in queue 6. Queue 6 length: 1
# 11:21:36: Stop serving customer in queue 5.  Queue 5 length: 2
# 11:21:36: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 5
# 11:21:36: Add customer to queue 5.  Queue length: 2
# 11:21:36: Stop serving customer in queue 3.  Queue 3 length: 2
# 11:21:36: Start serving customer in queue 3. Queue 3 length: 1
# Queue to add customer: 3
# 11:22:12: Add customer to queue 3.  Queue length: 2
# 11:22:12: Stop serving customer in queue 4.  Queue 4 length: 2
# 11:22:12: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 4
# 11:22:48: Add customer to queue 4.  Queue length: 2
# 11:22:48: Stop serving customer in queue 2.  Queue 2 length: 2
# 11:22:48: Start serving customer in queue 2. Queue 2 length: 1
# 11:22:48: Stop serving customer in queue 9.  Queue 9 length: 2
# 11:22:48: Start serving customer in queue 9. Queue 9 length: 1
# Queue to add customer: 2
# 11:23:24: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 6
# 11:23:24: Add customer to queue 6.  Queue length: 2
# 11:25:12: Stop serving customer in manager queue.  Queue 0 length: 1
# 11:25:12: Start serving customer in manager queue. Queue 0 length: 0
# 11:25:12: Stop serving customer in queue 6.  Queue 6 length: 2
# 11:25:12: Start serving customer in queue 6. Queue 6 length: 1
# 11:25:12: Stop serving customer in queue 3.  Queue 3 length: 2
# 11:25:12: Start serving customer in queue 3. Queue 3 length: 1
# Queue to add customer: 3
# 11:25:48: Add customer to queue 3.  Queue length: 2
# 11:25:48: Add customer to manager queue.  Queue length: 1
# Queue to add customer: 6
# 11:26:24: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 9
# 11:27:00: Add customer to queue 9.  Queue length: 2
# Queue to add customer: 1
# 11:27:36: Add customer to queue 1.  Queue length: 3
# 11:27:36: Stop serving customer in queue 2.  Queue 2 length: 2
# 11:27:36: Start serving customer in queue 2. Queue 2 length: 1
# 11:28:12: Stop serving customer in queue 6.  Queue 6 length: 2
# 11:28:12: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 2
# 11:28:48: Add customer to queue 2.  Queue length: 2
# 11:28:48: Stop serving customer in queue 8.  Queue 8 length: 2
# 11:28:48: Start serving customer in queue 8. Queue 8 length: 1
# 11:29:24: Stop serving customer in queue 7.  Queue 7 length: 2
# 11:29:24: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 6
# 11:29:24: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 7
# 11:30:00: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 8
# 11:30:36: Add customer to queue 8.  Queue length: 2
# 11:31:12: Stop serving customer in queue 2.  Queue 2 length: 2
# 11:31:12: Start serving customer in queue 2. Queue 2 length: 1
# 11:31:12: Stop serving customer in queue 1.  Queue 1 length: 3
# 11:31:12: Start serving customer in queue 1. Queue 1 length: 2
# 11:31:12: Stop serving customer in queue 4.  Queue 4 length: 2
# 11:31:12: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 2
# 11:31:12: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 4
# 11:31:48: Add customer to queue 4.  Queue length: 2
# 11:31:48: Stop serving customer in queue 3.  Queue 3 length: 2
# 11:31:48: Start serving customer in queue 3. Queue 3 length: 1
# Queue to add customer: 3
# 11:32:24: Add customer to queue 3.  Queue length: 2
# 11:33:00: Stop serving customer in queue 8.  Queue 8 length: 2
# 11:33:00: Start serving customer in queue 8. Queue 8 length: 1
# 11:33:00: Stop serving customer in queue 7.  Queue 7 length: 2
# 11:33:00: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 7
# 11:33:36: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 8
# 11:34:48: Add customer to queue 8.  Queue length: 2
# 11:34:48: Stop serving customer in queue 3.  Queue 3 length: 2
# 11:34:48: Start serving customer in queue 3. Queue 3 length: 1
# Queue to add customer: 3
# 11:35:24: Add customer to queue 3.  Queue length: 2
# Queue to add customer: 1
# 11:35:24: Add customer to queue 1.  Queue length: 3
# Queue to add customer: 2
# 11:35:24: Add customer to queue 2.  Queue length: 3
# 11:36:36: Stop serving customer in queue 6.  Queue 6 length: 2
# 11:36:36: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 6
# 11:37:12: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 3
# 11:37:48: Add customer to queue 3.  Queue length: 3
# 11:37:48: Add customer to manager queue.  Queue length: 2
# Queue to add customer: 4
# 11:39:00: Add customer to queue 4.  Queue length: 3
# 11:40:12: Stop serving customer in queue 4.  Queue 4 length: 3
# 11:40:12: Start serving customer in queue 4. Queue 4 length: 2
# 11:40:48: Stop serving customer in queue 5.  Queue 5 length: 2
# 11:40:48: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 5
# 11:40:48: Add customer to queue 5.  Queue length: 2
# 11:41:24: Stop serving customer in queue 8.  Queue 8 length: 2
# 11:41:24: Start serving customer in queue 8. Queue 8 length: 1
# 11:42:36: Stop serving customer in queue 1.  Queue 1 length: 3
# 11:42:36: Start serving customer in queue 1. Queue 1 length: 2
# 11:42:36: Stop serving customer in queue 9.  Queue 9 length: 2
# 11:42:36: Start serving customer in queue 9. Queue 9 length: 1
# 11:42:36: Stop serving customer in queue 7.  Queue 7 length: 2
# 11:42:36: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 7
# 11:43:12: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 8
# 11:43:48: Add customer to queue 8.  Queue length: 2
# Queue to add customer: 9
# 11:45:36: Add customer to queue 9.  Queue length: 2
# 11:46:12: Stop serving customer in queue 8.  Queue 8 length: 2
# 11:46:12: Start serving customer in queue 8. Queue 8 length: 1
# 11:46:48: Stop serving customer in queue 2.  Queue 2 length: 3
# 11:46:48: Start serving customer in queue 2. Queue 2 length: 2
# Queue to add customer: 8
# 11:46:48: Add customer to queue 8.  Queue length: 2
# 11:46:48: Stop serving customer in queue 3.  Queue 3 length: 3
# 11:46:48: Start serving customer in queue 3. Queue 3 length: 2
# Queue to add customer: 1
# 11:46:48: Add customer to queue 1.  Queue length: 3
# 11:46:48: Stop serving customer in queue 4.  Queue 4 length: 2
# 11:46:48: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 4
# 11:47:24: Add customer to queue 4.  Queue length: 2
# 11:47:24: Stop serving customer in queue 7.  Queue 7 length: 2
# 11:47:24: Start serving customer in queue 7. Queue 7 length: 1
# 11:48:36: Stop serving customer in manager queue.  Queue 0 length: 2
# 11:48:36: Start serving customer in manager queue. Queue 0 length: 1
# 11:49:12: Stop serving customer in queue 1.  Queue 1 length: 3
# 11:49:12: Start serving customer in queue 1. Queue 1 length: 2
# 11:49:48: Stop serving customer in queue 6.  Queue 6 length: 2
# 11:49:48: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 6
# 11:49:48: Add customer to queue 6.  Queue length: 2
# 11:49:48: Stop serving customer in queue 9.  Queue 9 length: 2
# 11:49:48: Start serving customer in queue 9. Queue 9 length: 1
# Queue to add customer: 7
# 11:49:48: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 9
# 11:50:24: Add customer to queue 9.  Queue length: 2
# Queue to add customer: 1
# 11:50:24: Add customer to queue 1.  Queue length: 3
# 11:52:48: Stop serving customer in queue 4.  Queue 4 length: 2
# 11:52:48: Start serving customer in queue 4. Queue 4 length: 1
# 11:52:48: Stop serving customer in queue 5.  Queue 5 length: 2
# 11:52:48: Start serving customer in queue 5. Queue 5 length: 1
# 11:52:48: Stop serving customer in queue 8.  Queue 8 length: 2
# 11:52:48: Start serving customer in queue 8. Queue 8 length: 1
# 11:53:24: Stop serving customer in queue 7.  Queue 7 length: 2
# 11:53:24: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 4
# 11:55:12: Add customer to queue 4.  Queue length: 2
# 11:55:48: Stop serving customer in queue 9.  Queue 9 length: 2
# 11:55:48: Start serving customer in queue 9. Queue 9 length: 1
# Queue to add customer: 5
# 11:56:24: Add customer to queue 5.  Queue length: 2
# 11:56:24: Add customer to manager queue.  Queue length: 2
# 11:56:24: Stop serving customer in queue 6.  Queue 6 length: 2
# 11:56:24: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 6
# 11:57:00: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 7
# 11:57:00: Add customer to queue 7.  Queue length: 2
# 11:57:36: Stop serving customer in queue 2.  Queue 2 length: 2
# 11:57:36: Start serving customer in queue 2. Queue 2 length: 1
# 11:57:36: Stop serving customer in queue 3.  Queue 3 length: 2
# 11:57:36: Start serving customer in queue 3. Queue 3 length: 1
# 11:58:12: Stop serving customer in queue 4.  Queue 4 length: 2
# 11:58:12: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 2
# 11:58:48: Add customer to queue 2.  Queue length: 2
# 11:59:24: Stop serving customer in queue 8.  Queue 8 length: 1
# 11:59:24: Start serving customer in queue 8. Queue 8 length: 0
# Queue to add customer: 8
# 11:59:24: Add customer to queue 8.  Queue length: 1
# 12:00:00: Stop serving customer in queue 1.  Queue 1 length: 3
# 12:00:00: Start serving customer in queue 1. Queue 1 length: 2
# 12:00:36: Stop serving customer in queue 3.  Queue 3 length: 1
# 12:00:36: Start serving customer in queue 3. Queue 3 length: 0
# Queue to add customer: 3
# 12:01:12: Add customer to queue 3.  Queue length: 1
# Queue to add customer: 3
# 12:02:24: Add customer to queue 3.  Queue length: 2
# 12:02:24: Stop serving customer in queue 8.  Queue 8 length: 1
# 12:02:24: Start serving customer in queue 8. Queue 8 length: 0
# Queue to add customer: 8
# 12:03:36: Add customer to queue 8.  Queue length: 1
# 12:03:36: Stop serving customer in queue 5.  Queue 5 length: 2
# 12:03:36: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 4
# 12:04:48: Add customer to queue 4.  Queue length: 2
# 12:06:00: Stop serving customer in queue 2.  Queue 2 length: 2
# 12:06:00: Start serving customer in queue 2. Queue 2 length: 1
# Queue to add customer: 2
# 12:06:00: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 5
# 12:07:12: Add customer to queue 5.  Queue length: 2
# 12:07:12: Stop serving customer in queue 6.  Queue 6 length: 2
# 12:07:12: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 6
# 12:07:12: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 8
# 12:07:48: Add customer to queue 8.  Queue length: 2
# Queue to add customer: 9
# 12:09:36: Add customer to queue 9.  Queue length: 2
# 12:09:36: Stop serving customer in queue 8.  Queue 8 length: 2
# 12:09:36: Start serving customer in queue 8. Queue 8 length: 1
# 12:10:12: Stop serving customer in queue 9.  Queue 9 length: 2
# 12:10:12: Start serving customer in queue 9. Queue 9 length: 1
# 12:11:24: Stop serving customer in queue 5.  Queue 5 length: 2
# 12:11:24: Start serving customer in queue 5. Queue 5 length: 1
# 12:11:24: Stop serving customer in queue 1.  Queue 1 length: 2
# 12:11:24: Start serving customer in queue 1. Queue 1 length: 1
# Queue to add customer: 1
# 12:11:24: Add customer to queue 1.  Queue length: 2
# 12:11:24: Add customer to manager queue.  Queue length: 3
# 12:11:24: Stop serving customer in queue 7.  Queue 7 length: 2
# 12:11:24: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 5
# 12:12:00: Add customer to queue 5.  Queue length: 2
# Queue to add customer: 7
# 12:13:12: Add customer to queue 7.  Queue length: 2
# 12:13:12: Stop serving customer in manager queue.  Queue 0 length: 3
# 12:13:12: Start serving customer in manager queue. Queue 0 length: 2
# Queue to add customer: 8
# 12:13:48: Add customer to queue 8.  Queue length: 2
# Queue to add customer: 9
# 12:13:48: Add customer to queue 9.  Queue length: 2
# Queue to add customer: 1
# 12:13:48: Add customer to queue 1.  Queue length: 3
# 12:13:48: Add customer to manager queue.  Queue length: 3
# 12:14:24: Stop serving customer in queue 5.  Queue 5 length: 2
# 12:14:24: Start serving customer in queue 5. Queue 5 length: 1
# 12:14:24: Stop serving customer in queue 3.  Queue 3 length: 2
# 12:14:24: Start serving customer in queue 3. Queue 3 length: 1
# Queue to add customer: 3
# 12:15:00: Add customer to queue 3.  Queue length: 2
# 12:15:00: Stop serving customer in queue 2.  Queue 2 length: 2
# 12:15:00: Start serving customer in queue 2. Queue 2 length: 1
# 12:15:00: Stop serving customer in queue 6.  Queue 6 length: 2
# 12:15:00: Start serving customer in queue 6. Queue 6 length: 1
# 12:17:24: Stop serving customer in queue 4.  Queue 4 length: 2
# 12:17:24: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 2
# 12:18:36: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 4
# 12:19:12: Add customer to queue 4.  Queue length: 2
# 12:19:48: Stop serving customer in queue 7.  Queue 7 length: 2
# 12:19:48: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 5
# 12:20:24: Add customer to queue 5.  Queue length: 2
# 12:21:00: Stop serving customer in queue 1.  Queue 1 length: 3
# 12:21:00: Start serving customer in queue 1. Queue 1 length: 2
# Queue to add customer: 6
# 12:21:00: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 7
# 12:21:36: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 1
# 12:21:36: Add customer to queue 1.  Queue length: 3
# 12:22:12: Stop serving customer in queue 5.  Queue 5 length: 2
# 12:22:12: Start serving customer in queue 5. Queue 5 length: 1
# 12:23:24: Stop serving customer in queue 6.  Queue 6 length: 2
# 12:23:24: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 5
# 12:23:24: Add customer to queue 5.  Queue length: 2
# 12:24:36: Stop serving customer in queue 2.  Queue 2 length: 2
# 12:24:36: Start serving customer in queue 2. Queue 2 length: 1
# 12:24:36: Stop serving customer in queue 8.  Queue 8 length: 2
# 12:24:36: Start serving customer in queue 8. Queue 8 length: 1
# Queue to add customer: 2
# 12:25:12: Add customer to queue 2.  Queue length: 2
# Queue to add customer: 6
# 12:25:48: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 8
# 12:25:48: Add customer to queue 8.  Queue length: 2
# Queue to add customer: 2
# 12:26:24: Add customer to queue 2.  Queue length: 3
# 12:27:00: Stop serving customer in queue 5.  Queue 5 length: 2
# 12:27:00: Start serving customer in queue 5. Queue 5 length: 1
# 12:27:36: Stop serving customer in manager queue.  Queue 0 length: 3
# 12:27:36: Start serving customer in manager queue. Queue 0 length: 2
# 12:28:48: Stop serving customer in queue 9.  Queue 9 length: 2
# 12:28:48: Start serving customer in queue 9. Queue 9 length: 1
# 12:30:00: Stop serving customer in queue 5.  Queue 5 length: 1
# 12:30:00: Start serving customer in queue 5. Queue 5 length: 0
# 12:30:36: Stop serving customer in queue 1.  Queue 1 length: 3
# 12:30:36: Start serving customer in queue 1. Queue 1 length: 2
# 12:30:36: Stop serving customer in queue 7.  Queue 7 length: 2
# 12:30:36: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 5
# 12:30:36: Add customer to queue 5.  Queue length: 1
# Queue to add customer: 5
# 12:33:00: Add customer to queue 5.  Queue length: 2
# 12:33:36: Stop serving customer in queue 2.  Queue 2 length: 3
# 12:33:36: Start serving customer in queue 2. Queue 2 length: 2
# Queue to add customer: 7
# 12:34:48: Add customer to queue 7.  Queue length: 2
# 12:36:00: Stop serving customer in queue 5.  Queue 5 length: 2
# 12:36:00: Start serving customer in queue 5. Queue 5 length: 1
# 12:36:36: Stop serving customer in queue 3.  Queue 3 length: 2
# 12:36:36: Start serving customer in queue 3. Queue 3 length: 1
# 12:36:36: Stop serving customer in queue 9.  Queue 9 length: 1
# 12:36:36: Start serving customer in queue 9. Queue 9 length: 0
# Queue to add customer: 9
# 12:36:36: Add customer to queue 9.  Queue length: 1
# Queue to add customer: 3
# 12:36:36: Add customer to queue 3.  Queue length: 2
# Queue to add customer: 5
# 12:37:48: Add customer to queue 5.  Queue length: 2
# Queue to add customer: 9
# 12:37:48: Add customer to queue 9.  Queue length: 2
# 12:37:48: Stop serving customer in queue 4.  Queue 4 length: 2
# 12:37:48: Start serving customer in queue 4. Queue 4 length: 1
# Queue to add customer: 4
# 12:38:24: Add customer to queue 4.  Queue length: 2
# 12:38:24: Stop serving customer in queue 1.  Queue 1 length: 2
# 12:38:24: Start serving customer in queue 1. Queue 1 length: 1
# 12:39:00: Stop serving customer in queue 2.  Queue 2 length: 2
# 12:39:00: Start serving customer in queue 2. Queue 2 length: 1
# 12:39:36: Stop serving customer in queue 6.  Queue 6 length: 2
# 12:39:36: Start serving customer in queue 6. Queue 6 length: 1
# 12:39:36: Stop serving customer in queue 3.  Queue 3 length: 2
# 12:39:36: Start serving customer in queue 3. Queue 3 length: 1
# 12:39:36: Stop serving customer in queue 7.  Queue 7 length: 2
# 12:39:36: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 1
# 12:40:12: Add customer to queue 1.  Queue length: 2
# Queue to add customer: 2
# 12:40:12: Add customer to queue 2.  Queue length: 2
# 12:40:48: Stop serving customer in queue 8.  Queue 8 length: 2
# 12:40:48: Start serving customer in queue 8. Queue 8 length: 1
# Queue to add customer: 3
# 12:40:48: Add customer to queue 3.  Queue length: 2
# Queue to add customer: 6
# 12:41:24: Add customer to queue 6.  Queue length: 2
# Queue to add customer: 7
# 12:42:36: Add customer to queue 7.  Queue length: 2
# 12:42:36: Stop serving customer in manager queue.  Queue 0 length: 2
# 12:42:36: Start serving customer in manager queue. Queue 0 length: 1
# 12:42:36: Stop serving customer in queue 3.  Queue 3 length: 2
# 12:42:36: Start serving customer in queue 3. Queue 3 length: 1
# 12:43:12: Stop serving customer in queue 6.  Queue 6 length: 2
# 12:43:12: Start serving customer in queue 6. Queue 6 length: 1
# Queue to add customer: 3
# 12:43:48: Add customer to queue 3.  Queue length: 2
# 12:43:48: Stop serving customer in queue 9.  Queue 9 length: 2
# 12:43:48: Start serving customer in queue 9. Queue 9 length: 1
# Queue to add customer: 6
# 12:43:48: Add customer to queue 6.  Queue length: 2
# 12:45:36: Stop serving customer in queue 5.  Queue 5 length: 2
# 12:45:36: Start serving customer in queue 5. Queue 5 length: 1
# Queue to add customer: 5
# 12:46:12: Add customer to queue 5.  Queue length: 2
# 12:46:12: Stop serving customer in queue 7.  Queue 7 length: 2
# 12:46:12: Start serving customer in queue 7. Queue 7 length: 1
# Queue to add customer: 7
# 12:46:12: Add customer to queue 7.  Queue length: 2
# Queue to add customer: 8
# 12:46:48: Add customer to queue 8.  Queue length: 2
# Queue to add customer: 9
# 12:47:24: Add customer to queue 9.  Queue length: 2
# Queue to add customer: 1
# 12:47:24: Add customer to queue 1.  Queue length: 3
# 12:47:24: Stop serving customer in queue 9.  Queue 9 length: 2
# 12:47:24: Start serving customer in queue 9. Queue 9 length: 1
# 12:48:00: Stop serving customer in queue 2.  Queue 2 length: 2
# 12:48:00: Start serving customer in queue 2. Queue 2 length: 1
# Queue to add customer: 2
# 12:48:36: Add customer to queue 2.  Queue length: 2
# 12:49:12: Stop serving customer in queue 1.  Queue 1 length: 3
# 12:49:12: Start serving customer in queue 1. Queue 1 length: 2
# Queue to add customer: 9
# 12:49:48: Add customer to queue 9.  Queue length: 2
# Queue to add customer: 1
# 12:49:48: Add customer to queue 1.  Queue length: 3
# ...
# Queue to add customer: 6
# 16:53:24: Add customer to queue 6.  Queue length: 3
# Queue to add customer: 7
# 16:54:00: Add customer to queue 7.  Queue length: 3
# Queue to add customer: 1
# 16:54:00: Add customer to queue 1.  Queue length: 4
# 16:54:36: Stop serving customer in manager queue.  Queue 0 length: 5
# 16:54:36: Start serving customer in manager queue. Queue 0 length: 4
# Queue to add customer: 5
# 16:55:12: Add customer to queue 5.  Queue length: 4
# 16:55:48: Stop serving customer in queue 3.  Queue 3 length: 4
# 16:55:48: Start serving customer in queue 3. Queue 3 length: 3
# 16:57:00: Stop serving customer in queue 1.  Queue 1 length: 4
# 16:57:00: Start serving customer in queue 1. Queue 1 length: 3
# Queue to add customer: 1
# 16:57:36: Add customer to queue 1.  Queue length: 4
# 16:57:36: Stop serving customer in queue 2.  Queue 2 length: 4
# 16:57:36: Start serving customer in queue 2. Queue 2 length: 3
# Queue to add customer: 2
# 16:57:36: Add customer to queue 2.  Queue length: 4
# 16:57:36: Add customer to manager queue.  Queue length: 5
# Queue to add customer: 3
# 16:57:36: Add customer to queue 3.  Queue length: 4
# 16:58:12: Stop serving customer in queue 8.  Queue 8 length: 3
# 16:58:12: Start serving customer in queue 8. Queue 8 length: 2
# 16:58:48: Stop serving customer in queue 5.  Queue 5 length: 4
# 16:58:48: Start serving customer in queue 5. Queue 5 length: 3
# Queue to add customer: 8
# 16:58:48: Add customer to queue 8.  Queue length: 3
# 16:58:48: Stop serving customer in queue 4.  Queue 4 length: 4
# 16:58:48: Start serving customer in queue 4. Queue 4 length: 3
# Queue to add customer: 4
# 16:59:24: Add customer to queue 4.  Queue length: 4
# Queue to add customer: 5
# 17:00:00: Add customer to queue 5.  Queue length: 4
# 17:00:00: Stop serving customer in queue 6.  Queue 6 length: 3
# 17:00:00: Start serving customer in queue 6. Queue 6 length: 2
# 17:00:36: Stop serving customer in queue 1.  Queue 1 length: 4
# 17:00:36: Start serving customer in queue 1. Queue 1 length: 3
# 17:01:48: Stop serving customer in queue 8.  Queue 8 length: 3
# 17:01:48: Start serving customer in queue 8. Queue 8 length: 2
# 17:03:00: Stop serving customer in queue 9.  Queue 9 length: 3
# 17:03:00: Start serving customer in queue 9. Queue 9 length: 2
# Queue to add customer: 6
# 17:03:00: Add customer to queue 6.  Queue length: 3
# 17:03:36: Stop serving customer in queue 6.  Queue 6 length: 3
# 17:03:36: Start serving customer in queue 6. Queue 6 length: 2
# 17:03:36: Stop serving customer in queue 5.  Queue 5 length: 4
# 17:03:36: Start serving customer in queue 5. Queue 5 length: 3
# 17:03:36: Stop serving customer in queue 7.  Queue 7 length: 3
# 17:03:36: Start serving customer in queue 7. Queue 7 length: 2
# Queue to add customer: 6
# 17:04:12: Add customer to queue 6.  Queue length: 3
# 17:04:48: Stop serving customer in queue 2.  Queue 2 length: 4
# 17:04:48: Start serving customer in queue 2. Queue 2 length: 3
# 17:05:24: Stop serving customer in queue 3.  Queue 3 length: 4
# 17:05:24: Start serving customer in queue 3. Queue 3 length: 3
# Queue to add customer: 7
# 17:05:24: Add customer to queue 7.  Queue length: 3
# Queue to add customer: 8
# 17:06:00: Add customer to queue 8.  Queue length: 3
# Queue to add customer: 9
# 17:06:36: Add customer to queue 9.  Queue length: 3
# 17:06:36: Add customer to manager queue.  Queue length: 6
# 17:07:48: Stop serving customer in queue 7.  Queue 7 length: 3
# 17:07:48: Start serving customer in queue 7. Queue 7 length: 2
# Queue to add customer: 7
# 17:07:48: Add customer to queue 7.  Queue length: 3
# Queue to add customer: 1
# 17:09:00: Add customer to queue 1.  Queue length: 4
# 17:09:36: Stop serving customer in queue 1.  Queue 1 length: 4
# 17:09:36: Start serving customer in queue 1. Queue 1 length: 3
# 17:10:48: Stop serving customer in queue 6.  Queue 6 length: 3
# 17:10:48: Start serving customer in queue 6. Queue 6 length: 2
# Queue to add customer: 6
# 17:10:48: Add customer to queue 6.  Queue length: 3
# Queue to add customer: 1
# 17:11:24: Add customer to queue 1.  Queue length: 4
# Queue to add customer: 2
# 17:11:24: Add customer to queue 2.  Queue length: 4
# 17:11:24: Stop serving customer in queue 9.  Queue 9 length: 3
# 17:11:24: Start serving customer in queue 9. Queue 9 length: 2
# Queue to add customer: 9
# 17:11:24: Add customer to queue 9.  Queue length: 3
# 17:12:36: Stop serving customer in queue 4.  Queue 4 length: 4
# 17:12:36: Start serving customer in queue 4. Queue 4 length: 3
# Queue to add customer: 3
# 17:13:12: Add customer to queue 3.  Queue length: 4
# Queue to add customer: 4
# 17:14:24: Add customer to queue 4.  Queue length: 4
# 17:14:24: Stop serving customer in queue 8.  Queue 8 length: 3
# 17:14:24: Start serving customer in queue 8. Queue 8 length: 2
# 17:15:00: Stop serving customer in queue 2.  Queue 2 length: 4
# 17:15:00: Start serving customer in queue 2. Queue 2 length: 3
# 17:15:00: Stop serving customer in manager queue.  Queue 0 length: 6
# 17:15:00: Start serving customer in manager queue. Queue 0 length: 5
# Queue to add customer: 8
# 17:15:36: Add customer to queue 8.  Queue length: 3
# Queue to add customer: 2
# 17:15:36: Add customer to queue 2.  Queue length: 4
# 17:15:36: Stop serving customer in queue 6.  Queue 6 length: 3
# 17:15:36: Start serving customer in queue 6. Queue 6 length: 2
# Queue to add customer: 6
# 17:15:36: Add customer to queue 6.  Queue length: 3
# Queue to add customer: 5
# 17:15:36: Add customer to queue 5.  Queue length: 4
# Queue to add customer: 6
# 17:16:12: Add customer to queue 6.  Queue length: 4
# Queue to add customer: 7
# 17:16:12: Add customer to queue 7.  Queue length: 4
# Queue to add customer: 8
# 17:16:48: Add customer to queue 8.  Queue length: 4
# Queue to add customer: 9
# 17:17:24: Add customer to queue 9.  Queue length: 4
# 17:17:24: Stop serving customer in queue 5.  Queue 5 length: 4
# 17:17:24: Start serving customer in queue 5. Queue 5 length: 3
# 17:18:00: Stop serving customer in queue 2.  Queue 2 length: 4
# 17:18:00: Start serving customer in queue 2. Queue 2 length: 3
# 17:18:00: Stop serving customer in queue 7.  Queue 7 length: 4
# 17:18:00: Start serving customer in queue 7. Queue 7 length: 3
# 17:18:00: Stop serving customer in queue 8.  Queue 8 length: 4
# 17:18:00: Start serving customer in queue 8. Queue 8 length: 3
# Queue to add customer: 2
# 17:18:36: Add customer to queue 2.  Queue length: 4
# Queue to add customer: 5
# 17:18:36: Add customer to queue 5.  Queue length: 4
# Queue to add customer: 7
# 17:19:12: Add customer to queue 7.  Queue length: 4
# 17:19:12: Stop serving customer in queue 3.  Queue 3 length: 4
# 17:19:12: Start serving customer in queue 3. Queue 3 length: 3
# Queue to add customer: 3
# 17:19:48: Add customer to queue 3.  Queue length: 4
# 17:20:24: Stop serving customer in queue 1.  Queue 1 length: 4
# 17:20:24: Start serving customer in queue 1. Queue 1 length: 3
# 17:21:36: Stop serving customer in queue 7.  Queue 7 length: 4
# 17:21:36: Start serving customer in queue 7. Queue 7 length: 3
# Queue to add customer: 1
# 17:22:12: Add customer to queue 1.  Queue length: 4
# Queue to add customer: 7
# 17:22:12: Add customer to queue 7.  Queue length: 4
# Queue to add customer: 8
# 17:22:12: Add customer to queue 8.  Queue length: 4
# Queue to add customer: 1
# 17:22:12: Add customer to queue 1.  Queue length: 5
# Queue to add customer: 2
# 17:22:12: Add customer to queue 2.  Queue length: 5
# Queue to add customer: 3
# 17:22:48: Add customer to queue 3.  Queue length: 5
# 17:22:48: Stop serving customer in queue 2.  Queue 2 length: 5
# 17:22:48: Start serving customer in queue 2. Queue 2 length: 4
# 17:23:24: Stop serving customer in queue 8.  Queue 8 length: 4
# 17:23:24: Start serving customer in queue 8. Queue 8 length: 3
# Queue to add customer: 8
# 17:23:24: Add customer to queue 8.  Queue length: 4
# 17:23:24: Add customer to manager queue.  Queue length: 6
# 17:23:24: Stop serving customer in queue 1.  Queue 1 length: 5
# 17:23:24: Start serving customer in queue 1. Queue 1 length: 4
# Queue to add customer: 1
# 17:24:36: Add customer to queue 1.  Queue length: 5
# Queue to add customer: 2
# 17:24:36: Add customer to queue 2.  Queue length: 5
# Queue to add customer: 4
# 17:24:36: Add customer to queue 4.  Queue length: 5
# Queue to add customer: 5
# 17:24:36: Add customer to queue 5.  Queue length: 5
# Queue to add customer: 6
# 17:25:48: Add customer to queue 6.  Queue length: 5
# Queue to add customer: 7
# 17:26:24: Add customer to queue 7.  Queue length: 5
# Queue to add customer: 8
# 17:26:24: Add customer to queue 8.  Queue length: 5
# 17:27:00: Stop serving customer in queue 8.  Queue 8 length: 5
# 17:27:00: Start serving customer in queue 8. Queue 8 length: 4
# 17:27:36: Stop serving customer in queue 2.  Queue 2 length: 5
# 17:27:36: Start serving customer in queue 2. Queue 2 length: 4
# Queue to add customer: 2
# 17:27:36: Add customer to queue 2.  Queue length: 5
# Queue to add customer: 8
# 17:28:12: Add customer to queue 8.  Queue length: 5
# Queue to add customer: 9
# 17:28:12: Add customer to queue 9.  Queue length: 5
# Queue to add customer: 1
# 17:28:12: Add customer to queue 1.  Queue length: 6
# Queue to add customer: 2
# 17:29:24: Add customer to queue 2.  Queue length: 6
# 17:30:00: Stop serving customer in queue 4.  Queue 4 length: 5
# 17:30:00: Start serving customer in queue 4. Queue 4 length: 4
# 17:30:36: Stop serving customer in queue 5.  Queue 5 length: 5
# 17:30:36: Start serving customer in queue 5. Queue 5 length: 4
# Queue to add customer: 4
# 17:30:36: Add customer to queue 4.  Queue length: 5
# 17:30:36: Stop serving customer in queue 3.  Queue 3 length: 5
# 17:30:36: Start serving customer in queue 3. Queue 3 length: 4
# 17:31:48: Stop serving customer in queue 7.  Queue 7 length: 5
# 17:31:48: Start serving customer in queue 7. Queue 7 length: 4
# 17:31:48: Stop serving customer in queue 6.  Queue 6 length: 5
# 17:31:48: Start serving customer in queue 6. Queue 6 length: 4
# Queue to add customer: 3
# 17:31:48: Add customer to queue 3.  Queue length: 5
# Queue to add customer: 5
# 17:32:24: Add customer to queue 5.  Queue length: 5
# Queue to add customer: 6
# 17:32:24: Add customer to queue 6.  Queue length: 5
# Queue to add customer: 7
# 17:33:00: Add customer to queue 7.  Queue length: 5
# 17:33:00: Stop serving customer in queue 8.  Queue 8 length: 5
# 17:33:00: Start serving customer in queue 8. Queue 8 length: 4
# Queue to add customer: 8
# 17:34:12: Add customer to queue 8.  Queue length: 5
# Queue to add customer: 3
# 17:34:12: Add customer to queue 3.  Queue length: 6
# Queue to add customer: 4
# 17:35:24: Add customer to queue 4.  Queue length: 6
# 17:35:24: Stop serving customer in queue 9.  Queue 9 length: 5
# 17:35:24: Start serving customer in queue 9. Queue 9 length: 4
# 17:36:00: Stop serving customer in queue 1.  Queue 1 length: 6
# 17:36:00: Start serving customer in queue 1. Queue 1 length: 5
# Queue to add customer: 9
# 17:36:36: Add customer to queue 9.  Queue length: 5
# 17:36:36: Add customer to manager queue.  Queue length: 7
# 17:37:12: Stop serving customer in queue 7.  Queue 7 length: 5
# 17:37:12: Start serving customer in queue 7. Queue 7 length: 4
# 17:37:12: Stop serving customer in queue 4.  Queue 4 length: 6
# 17:37:12: Start serving customer in queue 4. Queue 4 length: 5
# 17:37:12: Stop serving customer in queue 8.  Queue 8 length: 5
# 17:37:12: Start serving customer in queue 8. Queue 8 length: 4
# 17:41:24: Stop serving customer in queue 2.  Queue 2 length: 6
# 17:41:24: Start serving customer in queue 2. Queue 2 length: 5
# Queue to add customer: 7
# 17:42:00: Add customer to queue 7.  Queue length: 5
# 17:42:36: Stop serving customer in queue 8.  Queue 8 length: 4
# 17:42:36: Start serving customer in queue 8. Queue 8 length: 3
# 17:42:36: Stop serving customer in queue 3.  Queue 3 length: 6
# 17:42:36: Start serving customer in queue 3. Queue 3 length: 5
# 17:43:48: Stop serving customer in manager queue.  Queue 0 length: 7
# 17:43:48: Start serving customer in manager queue. Queue 0 length: 6
# 17:44:24: Stop serving customer in queue 4.  Queue 4 length: 5
# 17:44:24: Start serving customer in queue 4. Queue 4 length: 4
# 17:45:00: Stop serving customer in queue 7.  Queue 7 length: 5
# 17:45:00: Start serving customer in queue 7. Queue 7 length: 4
# 17:45:00: Stop serving customer in queue 5.  Queue 5 length: 5
# 17:45:00: Start serving customer in queue 5. Queue 5 length: 4
# 17:45:36: Stop serving customer in queue 1.  Queue 1 length: 5
# 17:45:36: Start serving customer in queue 1. Queue 1 length: 4
# 17:45:36: Stop serving customer in queue 9.  Queue 9 length: 5
# 17:45:36: Start serving customer in queue 9. Queue 9 length: 4
# 17:46:12: Stop serving customer in queue 2.  Queue 2 length: 5
# 17:46:12: Start serving customer in queue 2. Queue 2 length: 4
# Queue to add customer: 8
# 17:46:48: Add customer to queue 8.  Queue length: 4
# Queue to add customer: 1
# 17:48:00: Add customer to queue 1.  Queue length: 5
# Queue to add customer: 2
# 17:48:36: Add customer to queue 2.  Queue length: 5
# Queue to add customer: 4
# 17:48:36: Add customer to queue 4.  Queue length: 5
# Queue to add customer: 5
# 17:49:12: Add customer to queue 5.  Queue length: 5
# 17:49:12: Stop serving customer in queue 1.  Queue 1 length: 5
# 17:49:12: Start serving customer in queue 1. Queue 1 length: 4
# 17:50:24: Stop serving customer in queue 3.  Queue 3 length: 5
# 17:50:24: Start serving customer in queue 3. Queue 3 length: 4
# Queue to add customer: 1
# 17:50:24: Add customer to queue 1.  Queue length: 5
# 17:50:24: Stop serving customer in queue 6.  Queue 6 length: 5
# 17:50:24: Start serving customer in queue 6. Queue 6 length: 4
# 17:51:00: Stop serving customer in queue 5.  Queue 5 length: 5
# 17:51:00: Start serving customer in queue 5. Queue 5 length: 4
# 17:51:36: Stop serving customer in queue 9.  Queue 9 length: 4
# 17:51:36: Start serving customer in queue 9. Queue 9 length: 3
# Queue to add customer: 9
# 17:52:12: Add customer to queue 9.  Queue length: 4
# 17:53:24: Stop serving customer in queue 4.  Queue 4 length: 5
# 17:53:24: Start serving customer in queue 4. Queue 4 length: 4
# Queue to add customer: 3
# 17:53:24: Add customer to queue 3.  Queue length: 5
# Queue to add customer: 4
# 17:53:24: Add customer to queue 4.  Queue length: 5
# 17:54:00: Stop serving customer in queue 3.  Queue 3 length: 5
# 17:54:00: Start serving customer in queue 3. Queue 3 length: 4
# Queue to add customer: 3
# 17:54:36: Add customer to queue 3.  Queue length: 5
# Queue to add customer: 5
# 17:55:48: Add customer to queue 5.  Queue length: 5
# Queue to add customer: 6
# 17:56:24: Add customer to queue 6.  Queue length: 5
# Queue to add customer: 7
# 17:57:00: Add customer to queue 7.  Queue length: 5
# Queue to add customer: 8
# 17:57:00: Add customer to queue 8.  Queue length: 5
# 17:57:00: Stop serving customer in queue 8.  Queue 8 length: 5
# 17:57:00: Start serving customer in queue 8. Queue 8 length: 4
# 17:58:12: Stop serving customer in queue 7.  Queue 7 length: 5
# 17:58:12: Start serving customer in queue 7. Queue 7 length: 4
# 17:58:12: Stop serving customer in queue 4.  Queue 4 length: 5
# 17:58:12: Start serving customer in queue 4. Queue 4 length: 4
# 17:58:48: Stop serving customer in queue 5.  Queue 5 length: 5
# 17:58:48: Start serving customer in queue 5. Queue 5 length: 4
# Queue to add customer: 4
# 17:59:24: Add customer to queue 4.  Queue length: 5
# Queue to add customer: 5
# 18:00:00: Add customer to queue 5.  Queue length: 5
# Total customers arrived in queue 0 is 32
# Total customers served in queue 0 is 25
# Total customers arrived in queue 1 is 64
# Total customers served in queue 1 is 58
# Total customers arrived in queue 2 is 63
# Total customers served in queue 2 is 57
# Total customers arrived in queue 3 is 64
# Total customers served in queue 3 is 58
# Total customers arrived in queue 4 is 69
# Total customers served in queue 4 is 63
# Total customers arrived in queue 5 is 65
# Total customers served in queue 5 is 59
# Total customers arrived in queue 6 is 58
# Total customers served in queue 6 is 52
# Total customers arrived in queue 7 is 59
# Total customers served in queue 7 is 54
# Total customers arrived in queue 8 is 66
# Total customers served in queue 8 is 61
# Total customers arrived in queue 9 is 55
# Total customers served in queue 9 is 50
# Average waiting time in minutes is 26.50474383301708

# %%
#define a run_simulation function that does not return grocery store but return the average waiting time
def run_simulation2(arrival_rate, service_rate, service_time_variance, 
                    manager_rate, manager_time_variance, run_until, nqueue):
    schedule = Schedule()
    grocery_store = GroceryStore(
        arrival_rate, service_rate, service_time_variance, manager_rate, manager_time_variance, nqueue)
    grocery_store.run(schedule)
    while schedule.next_event_time() < run_until:
        schedule.run_next_event()
    list_waiting_time=[]
    for i in grocery_store.list_of_queue:
        for j in range(len(i.list_departure_time)-1):
            list_waiting_time.append(i.list_departure_time[j]-i.list_arrival_time[j])
    avg_waiting_time = np.mean(list_waiting_time)*60 #in terms of minutes
    return np.mean(list_waiting_time)*60 #return average waiting time

# %%
# %%capture 
#disable all print statements
arrival = 60
service = 3/60
service_variance = 1/60
manager = 4/60
manager_variance = 1/60
duration = 18
service_time_variance = 1/60
list_avg_waiting_time=[[],[],[],[],[],[],[],[],[],[]] #list of 10 blank lists
for i in range(1,11): #try with different number of queues
    for j in range(100): #run 100 trials
        list_avg_waiting_time[i-1].append(
            run_simulation2(arrival, service, service_variance, manager, manager_variance, duration, i))

# %%
#calculate expected value and 95% confidence interval of average waiting time 
x=np.arange(1,11)
expected_avg_waiting_time = []
waiting_error = []
for i in list_avg_waiting_time:
    expected_avg_waiting_time.append(np.mean(i))
    std_error_waiting_time = sts.sem(i)
    print("95% confidence interval for", list_avg_waiting_time.index(i)+1, "queue(s) is", 
         [round(np.mean(i) - 1.96*std_error_waiting_time,2),round(np.mean(i) + 1.96*std_error_waiting_time,2)], "minutes")
    waiting_error.append(std_error_waiting_time*1.96)
plt.figure()
plt.errorbar(x, expected_avg_waiting_time, waiting_error, color="black", marker='o', linestyle='--')
plt.title("Average waiting time along with 95% confidence interval for different number of queues")
plt.xlabel("Number of queues")
plt.ylabel("Average waiting time (minutes)")
plt.show()
# Out:
# 95% confidence interval for 1 queue(s) is [187.92, 192.77] minutes
# 95% confidence interval for 2 queue(s) is [183.82, 187.48] minutes
# 95% confidence interval for 3 queue(s) is [167.8, 171.82] minutes
# 95% confidence interval for 4 queue(s) is [144.09, 147.93] minutes
# 95% confidence interval for 5 queue(s) is [120.92, 125.61] minutes
# 95% confidence interval for 6 queue(s) is [93.89, 98.29] minutes
# 95% confidence interval for 7 queue(s) is [71.01, 75.83] minutes
# 95% confidence interval for 8 queue(s) is [46.88, 51.28] minutes
# 95% confidence interval for 9 queue(s) is [28.12, 31.21] minutes
# 95% confidence interval for 10 queue(s) is [19.8, 20.84] minutes

# %% [markdown]
# We see in the above graph (and the ones below as well) that the confidence intervals are small compared to the actual data points (since we have 100 trials our certainty is high). Therefore, they are barely visible in the error plot. Therefore, I have made a series of print statements to clarify the confidence intervals.

# %%
#define a run_simulation function that does not return grocery store but return the max queue length
def run_simulation3(arrival_rate, service_rate, service_time_variance, 
                    manager_rate, manager_time_variance, run_until, nqueue):
    schedule = Schedule()
    grocery_store = GroceryStore(
        arrival_rate, service_rate, service_time_variance, manager_rate, manager_time_variance, nqueue)
    grocery_store.run(schedule)
    while schedule.next_event_time() < run_until:
        schedule.run_next_event()
    max_queue_length=0
    for i in grocery_store.list_of_queue:
        if i.max_queue_length > max_queue_length:
            max_queue_length = i.max_queue_length
    return max_queue_length

# %%
# %%capture 
#disable all print statements
arrival = 60
service = 3/60
service_variance = 1/60
manager = 4/60
manager_variance = 1/60
duration = 18
service_time_variance = 1/60
list_max_queue_length=[[],[],[],[],[],[],[],[],[],[]] #list of 10 blank lists
for i in range(1,11):
    for j in range(100):
        list_max_queue_length[i-1].append(
            run_simulation3(arrival, service, service_variance, manager, manager_variance, duration, i))

# %%
#calculate expected value and 95% confidence interval of max queue length 
x=np.arange(1,11)
expected_max_queue_length = []
max_queue_error = []
for i in list_max_queue_length:
    expected_max_queue_length.append(np.mean(i))
    std_error_max_queue_length = sts.sem(i)
    print("95% confidence interval for", list_max_queue_length.index(i)+1, "queue(s) is", 
         [round(np.mean(i) - 1.96*std_error_max_queue_length,2),
          round(np.mean(i) + 1.96*std_error_max_queue_length,2)], "customers")
    max_queue_error.append(std_error_max_queue_length*1.96)
plt.figure()
plt.errorbar(x, expected_max_queue_length, max_queue_error, color="black", marker='o', linestyle='--')
plt.title("Average max queue length along with 95% confidence interval for different number of queues")
plt.xlabel("Number of queues")
plt.ylabel("Average max queue length (customers)")
plt.show()
# Out:
# 95% confidence interval for 1 queue(s) is [475.53, 484.25] customers
# 95% confidence interval for 2 queue(s) is [207.01, 211.99] customers
# 95% confidence interval for 3 queue(s) is [120.76, 123.78] customers
# 95% confidence interval for 4 queue(s) is [74.8, 77.12] customers
# 95% confidence interval for 5 queue(s) is [48.85, 50.99] customers
# 95% confidence interval for 6 queue(s) is [30.75, 32.05] customers
# 95% confidence interval for 7 queue(s) is [19.53, 20.89] customers
# 95% confidence interval for 8 queue(s) is [10.33, 11.51] customers
# 95% confidence interval for 9 queue(s) is [4.51, 5.15] customers
# 95% confidence interval for 10 queue(s) is [2.61, 2.89] customers

# %% [markdown]
# ### Proposed third quantity: average queue length throughout the day
#
# Details and explanation to be provided in the report.

# %%
#define a run_simulation function that does not return grocery store but return the average queue length
def run_simulation4(arrival_rate, service_rate, service_time_variance, 
                    manager_rate, manager_time_variance, run_until, nqueue):
    schedule = Schedule()
    grocery_store = GroceryStore(
        arrival_rate, service_rate, service_time_variance, manager_rate, manager_time_variance, nqueue)
    grocery_store.run(schedule)
    while schedule.next_event_time() < run_until:
        schedule.run_next_event()
    list_queue_length=[]
    for i in grocery_store.list_of_queue:
        for j in range(len(i.list_arrival_time)-1):
            list_queue_length.append(i.people_in_queue)
    avg_queue_length = np.mean(list_queue_length) 
    return avg_queue_length

# %%
# %%capture 
#disable all print statements
arrival = 60
service = 3/60
service_variance = 1/60
manager = 4/60
manager_variance = 1/60
duration = 18
service_time_variance = 1/60
list_avg_queue_length=[[],[],[],[],[],[],[],[],[],[]] #list of 10 blank lists
for i in range(1,11):
    for j in range(100):
        list_avg_queue_length[i-1].append(
            run_simulation4(arrival, service, service_variance, manager, manager_variance, duration, i))

# %%
#calculate expected value and 95% confidence interval of average queue length
x=np.arange(1,11)
expected_avg_queue_length = []
avg_queue_error = []
for i in list_avg_queue_length:
    expected_avg_queue_length.append(np.mean(i))
    std_error_avg_queue_length = sts.sem(i)
    print("95% confidence interval for", list_avg_queue_length.index(i)+1, "queue(s) is", 
         [round(np.mean(i) - 1.96*std_error_avg_queue_length,2),
          round(np.mean(i) + 1.96*std_error_avg_queue_length,2)], "customers")
    avg_queue_error.append(std_error_avg_queue_length*1.96)
plt.figure()
plt.errorbar(x, expected_avg_queue_length, avg_queue_error, color="black", marker='o', linestyle='--')
plt.title("Average mean queue length along with 95% confidence interval for different number of queues")
plt.xlabel("Number of queues")
plt.ylabel("Average mean queue length (customers)")
plt.show()
# Out:
# 95% confidence interval for 1 queue(s) is [451.3, 461.03] customers
# 95% confidence interval for 2 queue(s) is [200.93, 205.64] customers
# 95% confidence interval for 3 queue(s) is [114.82, 117.74] customers
# 95% confidence interval for 4 queue(s) is [71.53, 73.98] customers
# 95% confidence interval for 5 queue(s) is [46.42, 48.35] customers
# 95% confidence interval for 6 queue(s) is [29.37, 31.0] customers
# 95% confidence interval for 7 queue(s) is [17.35, 18.83] customers
# 95% confidence interval for 8 queue(s) is [8.8, 9.96] customers
# 95% confidence interval for 9 queue(s) is [2.67, 3.4] customers
# 95% confidence interval for 10 queue(s) is [1.05, 1.26] customers
